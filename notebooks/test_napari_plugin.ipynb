# %%
# a notebook test of loading a validated json from path within a notebook
# %gui qt5
import napari
v = napari.Viewer()

# %%
v.open('/home/chris/src/yt_/analysis/napari-ytschema/napari_ytschema/test_json.json')
# Out:
# YESSSSSSSSSSSSSS
# yt : [INFO     ] 2021-07-01 11:54:55,069 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2021-07-01 11:54:55,070 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2021-07-01 11:54:55,071 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-01 11:54:55,071 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-01 11:54:55,072 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2021-07-01 11:54:55,128 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2021-07-01 11:54:55,128 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2021-07-01 11:54:55,129 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-01 11:54:55,130 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-01 11:54:55,131 Parameters: cosmological_simulation   = 0
# ...

# %%
from napari.utils import nbscreenshot
nbscreenshot(v)
