# %% [markdown]
# ## interpolation of node to cell centers
#
# xarray has routines for interpolating data...

# %%
from yt_xarray.sample_data import load_random_xr_data
import numpy as np 
import scipy
from dask import array as da
import xarray as xr

# %%
fields = {'temperature': ('x', 'y', 'z'), 'pressure': ('x', 'y', 'z')}
dims = {'x': (0,1,15), 'y': (0, 1, 10), 'z': (0, 1, 15)}
ds_xr = load_random_xr_data(fields, dims, length_unit='m')
ds_xr
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 15, y: 10, z: 15)
# Coordinates:
#   * x            (x) float64 0.0 0.07143 0.1429 0.2143 ... 0.8571 0.9286 1.0
#   * y            (y) float64 0.0 0.1111 0.2222 0.3333 ... 0.7778 0.8889 1.0
#   * z            (z) float64 0.0 0.07143 0.1429 0.2143 ... 0.8571 0.9286 1.0
# Data variables:
#     temperature  (x, y, z) float64 0.7353 0.7915 0.7455 ... 0.1293 0.259 0.6771
#     pressure     (x, y, z) float64 0.3653 0.6565 0.9118 ... 0.6826 0.6444 0.774
# Attributes:
#     geospatial_vertical_units:  m

# %%
ds_xr.temperature.x.isel({"x": slice(0, 4)})
# Out:
# <xarray.DataArray 'x' (x: 4)>
# array([0.      , 0.071429, 0.142857, 0.214286])
# Coordinates:
#   * x        (x) float64 0.0 0.07143 0.1429 0.2143

# %%
def select_yt_cell_centers(ds_xr, si, ei, field, 
                           method="select_then_interp",                          ):
    # si, ei : cell center si, ei

    xr_field = getattr(ds_xr, field)
    ei_node = ei + np.array([1,1,1])

    i_select_dict = {}    
    for idim, dim in enumerate(("x", "y", "z")):
        i_select_dict[dim] = slice(si[idim], ei_node[idim])        

    if method == "select_then_interp":
        # option 1: subselect then interpolation : dask safe!
        # but if not using linear interpolation, would need to
        # consider ghost nodes to avoid boundary effects between
        # chunks.
        data_subselection = xr_field.isel(i_select_dict).load()
        interp_dict = {}
        for idim, dim in enumerate(("x", "y", "z")):
            dim_vals = getattr(data_subselection, dim).values
            interp_dict[dim] = (dim_vals[1:] + dim_vals[:-1])/2.

        return data_subselection.interp(interp_dict).values
    
    elif method == "direct_interp":
        # option 2: interpolate without subselecting first : this
        # likely wont scale super well for memory use, but would
        # be po
        interp_dict = {}
        for idim, dim in enumerate(("x", "y", "z")):
            dim_vals = getattr(xr_field, dim).isel({dim:i_select_dict[dim]}).values
            interp_dict[dim] = (dim_vals[1:] + dim_vals[:-1])/2.
            
        return xr_field.interp(interp_dict).values

# %% [markdown]
# whole-grid selection:

# %%
ds_xr.temperature.shape
# Out:
# (15, 10, 15)

# %%
si = np.array([0, 0, 0])
ei = np.array(ds_xr.temperature.shape) - 1
fld = "temperature"
data_s_then_i = select_yt_cell_centers(ds_xr, si, ei, fld, method="direct_interp")
data_i = select_yt_cell_centers(ds_xr, si, ei, fld, method="select_then_interp")

# %%
data_s_then_i.shape, data_i.shape
# Out:
# ((14, 9, 14), (14, 9, 14))

# %%
# %%timeit
meth = "direct_interp"
data = select_yt_cell_centers(ds_xr, si, ei, fld, method="direct_interp")
data.shape
# Out:
# 4.02 ms ± 84.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
meth = "select_then_interp"
data = select_yt_cell_centers(ds_xr, si, ei, fld, method="select_then_interp")
data.shape
# Out:
# 3.76 ms ± 44.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def build_and_select(nx, ny ,nz, method):

    fields = {'temperature': ('x', 'y', 'z'), 
              'pressure': ('x', 'y', 'z')}
    dims = {'x': (0,1,nx), 'y': (0, 1, ny), 'z': (0, 1, nz)}
    ds_xr = load_random_xr_data(fields, dims, length_unit='m')

    # select the whole grid 
    si = np.array([0, 0, 0])
    ei = np.array(ds_xr.temperature.shape) - 1
    
        
    data = select_yt_cell_centers(ds_xr, 
                                  si, 
                                  ei, 
                                  'temperature',
                                 method=method)
    return data

# %%
data_s_then_i = build_and_select(100, 100, 100, "select_then_interp")

# %%
data_i = build_and_select(100, 100, 100, "direct_interp")

# %%
# %%timeit
data_i = build_and_select(100, 100, 100, "direct_interp")
# Out:
# 40.2 ms ± 1.57 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
data_i = build_and_select(100, 100, 100, "select_then_interp")
# Out:
# 41.3 ms ± 1.06 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
data_i = build_and_select(300, 300, 300, "direct_interp")
# Out:
# 1.07 s ± 20.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data_i = build_and_select(300, 300, 300, "select_then_interp")
# Out:
# 1.12 s ± 32.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data_i = build_and_select(500, 400, 600, "direct_interp")
# Out:
# 5.4 s ± 140 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data_i = build_and_select(500, 400, 600, "select_then_interp")
# Out:
# 5.41 s ± 89.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
from dask import array as da

# %%
nx = 500
ny = 400
nz = 600
chunks = 50
data_vals = da.random.random((nx,ny,nz), chunks=chunks)
coords = {'x': np.linspace(0,1, nx), 
          'y': np.linspace(0,1,ny),
          'z': np.linspace(0,1,nz)
         }
field_dims = ("x", "y", "z")
data = xr.DataArray(data_vals, 
                           coords=coords, 
                           dims=field_dims)

xr_ds = xr.Dataset({"temperature": data})

# %%
T = xr_ds.temperature.isel({'x':slice(0,20), 'y':slice(0,21), 'z':slice(0,19)})
T
# Out:
# <xarray.DataArray 'temperature' (x: 20, y: 21, z: 19)>
# dask.array<getitem, shape=(20, 21, 19), dtype=float64, chunksize=(20, 21, 19), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 0.0 0.002004 0.004008 ... 0.03407 0.03607 0.03808
#   * y        (y) float64 0.0 0.002506 0.005013 ... 0.04511 0.04762 0.05013
#   * z        (z) float64 0.0 0.001669 0.003339 ... 0.02671 0.02838 0.03005

# %%
T_in_mem = T.load()  #

# %%
si = np.array([0, 0, 0])
ei = np.array([11,12,13])
fld = "temperature"
data_i = select_yt_cell_centers(xr_ds, si, ei, fld, method="select_then_interp")
data_i.shape
# Out:
# (11, 12, 13)

# %%
data_s_then_i = select_yt_cell_centers(ds_xr, si, ei, fld, method="direct_interp")
data_s_then_i.shape
# Out:
# (11, 12, 13)

# %%
fields = {'temperature': ('x', 'y', 'z'), 'pressure': ('x', 'y', 'z')}
dims = {'x': (0,1,95), 'y': (0, 1, 42), 'z': (0, 1, 35)}
ds_xr = load_random_xr_data(fields, dims, length_unit='m')
T = ds_xr.temperature.isel({'x':slice(0,20), 'y':slice(0,21), 'z':slice(0,19)})

# %%
si = np.array([0, 0, 0])
ei = np.array(ds_xr.temperature.shape) - 1
fld = "temperature"

# %%
x = [1,2,3,4]
xr_ds.temperature.interp({"x": coords['x'][0:5], 
                          "y": coords['y'][0:5], 
                          "z": coords['z'][0:5], })
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [76], line 2
#       1 x = [1,2,3,4]
# ----> 2 xr_ds.temperature.interp({"x": coords['x'][0:5],
#       3                           "y": coords['y'][0:5],
#       4                           "z": coords['z'][0:5], })
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/dataarray.py:2074, in DataArray.interp(self, coords, method, assume_sorted, kwargs, **coords_kwargs)
#    2069 if self.dtype.kind not in "uifc":
#    2070     raise TypeError(
#    2071         "interp only works for a numeric type array. "
#    2072         "Given {}.".format(self.dtype)
#    2073     )
# -> 2074 ds = self._to_temp_dataset().interp(
#    2075     coords,
#    2076     method=method,
#    2077     kwargs=kwargs,
#    2078     assume_sorted=assume_sorted,
#    2079     **coords_kwargs,
#    2080 )
#    2081 return self._from_temp_dataset(ds)
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/dataset.py:3301, in Dataset.interp(self, coords, method, assume_sorted, kwargs, method_non_numeric, **coords_kwargs)
#    3294     sdims = (
#    3295         set(self.dims)
#    3296         .intersection(*[set(nx.dims) for nx in indexers.values()])
#    3297         .difference(coords.keys())
#    3298     )
#    3299     indexers.update({d: self.variables[d] for d in sdims})
# -> 3301 obj = self if assume_sorted else self.sortby([k for k in coords])
#    3303 def maybe_variable(obj, k):
#    3304     # workaround to get variable for dimension without coordinate.
#    3305     try:
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/dataset.py:6967, in Dataset.sortby(self, variables, ascending)
#    6965     order = np.lexsort(tuple(reversed(arrays)))
#    6966     indices[key] = order if ascending else order[::-1]
# -> 6967 return aligned_self.isel(indices)
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/dataset.py:2423, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2421 var_indexers = {k: v for k, v in indexers.items() if k in var.dims}
#    2422 if var_indexers:
# -> 2423     var = var.isel(var_indexers)
#    2424     if drop and var.ndim == 0 and name in coord_names:
#    2425         coord_names.remove(name)
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/variable.py:1274, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1271 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1273 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1274 return self[key]
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/variable.py:821, in Variable.__getitem__(self, key)
#     808 """Return a new Variable object whose contents are consistent with
#     809 getting the provided key from the underlying data.
#     810
#    (...)
#     818 array `x.values` directly.
#     819 """
#     820 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 821 data = as_indexable(self._data)[indexer]
#     822 if new_order:
#     823     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/xarray/core/indexing.py:1264, in NumpyIndexingAdapter.__getitem__(self, key)
#    1262 def __getitem__(self, key):
#    1263     array, key = self._indexing_array_and_key(key)
# -> 1264     return array[key]
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/dask/array/core.py:1993, in Array.__getitem__(self, index)
#    1990     return self
#    1992 out = "getitem-" + tokenize(self, index2)
# -> 1993 dsk, chunks = slice_array(out, self.name, self.chunks, index2, self.itemsize)
#    1995 graph = HighLevelGraph.from_collections(out, dsk, dependencies=[self])
#    1997 meta = meta_from_array(self._meta, ndim=len(chunks))
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/dask/array/slicing.py:174, in slice_array(out_name, in_name, blockdims, index, itemsize)
#     171 index += (slice(None, None, None),) * missing
#     173 # Pass down to next function
# --> 174 dsk_out, bd_out = slice_with_newaxes(out_name, in_name, blockdims, index, itemsize)
#     176 bd_out = tuple(map(tuple, bd_out))
#     177 return dsk_out, bd_out
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/dask/array/slicing.py:196, in slice_with_newaxes(out_name, in_name, blockdims, index, itemsize)
#     193         where_none[i] -= n
#     195 # Pass down and do work
# --> 196 dsk, blockdims2 = slice_wrap_lists(out_name, in_name, blockdims, index2, itemsize)
#     198 if where_none:
#     199     expand = expander(where_none)
#
# File ~/miniconda3/envs/yt_xarray/lib/python3.10/site-packages/dask/array/slicing.py:242, in slice_wrap_lists(out_name, in_name, blockdims, index, itemsize)
#     238 where_list = [
#     239     i for i, ind in enumerate(index) if is_arraylike(ind) and ind.ndim > 0
#     240 ]
#     241 if len(where_list) > 1:
# --> 242     raise NotImplementedError("Don't yet support nd fancy indexing")
#     243 # Is the single list an empty list? In this case just treat it as a zero
#     244 # length slice
#     245 if where_list and not index[where_list[0]].size:
#
# NotImplementedError: Don't yet support nd fancy indexing

# %%
type(xr_ds.temperature)
# Out:
# xarray.core.dataarray.DataArray

# %%
xr_ds.temperature.data
# Out:
# dask.array<random_sample, shape=(500, 400, 600), dtype=float64, chunksize=(50, 50, 50), chunktype=numpy.ndarray>
