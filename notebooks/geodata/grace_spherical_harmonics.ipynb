# %%
import yt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_16862/4251809393.py in <module>
# ----> 1 import yt
#       2 import pandas as pd
#
# ~/src/yt_/yt_dev/yt/yt/__init__.py in <module>
#      11 import yt.units as units
#      12 import yt.utilities.physical_constants as physical_constants
# ---> 13 from yt.data_objects.api import (
#      14     DatasetSeries,
#      15     ImageArray,
#
# ~/src/yt_/yt_dev/yt/yt/data_objects/api.py in <module>
# ----> 1 from . import construction_data_containers as __cdc, selection_objects as __sdc
#       2 from .analyzer_objects import AnalysisTask, analysis_task
#       3 from .image_array import ImageArray
#       4 from .index_subobjects import AMRGridPatch, OctreeSubset
#       5 from .particle_filters import add_particle_filter, particle_filter
#
# ...
