# %%
import yt

# %%
ds = yt.load_sample("IsolatedGalaxy")
# Out:
# yt : [INFO     ] 2022-06-30 10:44:57,091 Sample dataset found in '/home/chavlin/hdd/data/yt_data/yt_sample_sets/IsolatedGalaxy/galaxy0030/galaxy0030'
# yt : [INFO     ] 2022-06-30 10:44:57,171 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2022-06-30 10:44:57,172 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2022-06-30 10:44:57,172 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-30 10:44:57,173 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-30 10:44:57,173 Parameters: cosmological_simulation   = 0

# %%
slc = yt.SlicePlot(ds, "x", ("gas", "density"))
# Out:
# Parsing Hierarchy : 100%|██████████████████| 173/173 [00:00<00:00, 10071.13it/s]
# yt : [INFO     ] 2022-06-30 10:45:13,119 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2022-06-30 10:45:14,191 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-30 10:45:14,191 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-30 10:45:14,192 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-30 10:45:14,193 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-30 10:45:14,195 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
slc.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slc.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
import gc

del ds
gc.collect()
# Out:
# 22395

# %%
slc
# Out:
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# ~/miniconda3/envs/yt_dev/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/src/yt_general/yt/yt/visualization/_commons.py in newfunc(self, *args, **kwargs)
#     145             # call plot.run_callbacks()
#     146             self._setup_plots()
# --> 147         retv = f(self, *args, **kwargs)
#     148         return retv
#     149
#
# ~/src/yt_general/yt/yt/visualization/plot_container.py in _repr_html_(self)
#     636         ret = ""
#     637         for field in self.plots:
# --> 638             img = base64.b64encode(self.plots[field]._repr_png_()).decode()
# ...

# %%
ds = yt.load_sample("IsolatedGalaxy")
slc = yt.SlicePlot(ds, "x", ("gas", "density"))
# Out:
# yt : [INFO     ] 2022-06-30 10:47:53,140 Sample dataset found in '/home/chavlin/hdd/data/yt_data/yt_sample_sets/IsolatedGalaxy/galaxy0030/galaxy0030'
# yt : [INFO     ] 2022-06-30 10:47:53,195 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2022-06-30 10:47:53,195 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2022-06-30 10:47:53,196 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-30 10:47:53,196 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-30 10:47:53,197 Parameters: cosmological_simulation   = 0
# Parsing Hierarchy : 100%|██████████████████| 173/173 [00:00<00:00, 20472.72it/s]
# yt : [INFO     ] 2022-06-30 10:47:53,212 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2022-06-30 10:47:54,186 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-30 10:47:54,186 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-30 10:47:54,187 xlim = 0.000000 1.000000
# ...

# %%
p = slc.export_to_mpl_figure((1,1))

# %%
del ds
gc.collect()
# Out:
# 50113

# %%
p

# %%
p.savefig('temp.png')
