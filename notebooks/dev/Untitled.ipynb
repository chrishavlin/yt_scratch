# %%
import yt
import numpy as np 

num_particles = 1000

data = {
    ("b", "particle_position_x"): np.random.random(size=num_particles),
    ("b", "particle_position_y"): np.random.random(size=num_particles),
    ("b", "particle_position_z"): np.random.random(size=num_particles),
    ("b", "particle_velocity_x"): np.random.random(size=num_particles),
    ("b", "particle_velocity_y"): np.random.random(size=num_particles),
    ("b", "particle_velocity_z"): np.random.random(size=num_particles),
    ("b", "particle_mass"): np.ones(num_particles),
    ("b", "density"): np.ones(num_particles),
    ("b", "what"): np.ones(num_particles),
    ("b", "smoothing_length"): np.ones(num_particles),
    ("dm", "particle_position_x"): np.random.random(size=num_particles),
    ("dm", "particle_position_y"): np.random.random(size=num_particles),
    ("dm", "particle_position_z"): np.random.random(size=num_particles),
    ("dm", "particle_velocity_x"): np.random.random(size=num_particles),
    ("dm", "particle_velocity_y"): np.random.random(size=num_particles),
    ("dm", "particle_velocity_z"): np.random.random(size=num_particles),
    ("dm", "particle_mass"): np.ones(num_particles),
    ("dm", "density"): np.ones(num_particles),
    ("dm", "smoothing_length"): np.ones(num_particles),
}

ds = yt.load_particles(data)
ds.particle_types
# Out:
# yt : [INFO     ] 2023-10-31 14:53:04,893 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-10-31 14:53:04,894 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2023-10-31 14:53:04,894 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-10-31 14:53:04,894 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-10-31 14:53:04,895 Parameters: cosmological_simulation   = 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 28>()
#       4 num_particles = 1000
#       6 data = {
#       7     ("b", "particle_position_x"): np.random.random(size=num_particles),
#       8     ("b", "particle_position_y"): np.random.random(size=num_particles),
#    (...)
#      25     ("dm", "smoothing_length"): np.ones(num_particles),
#      26 }
# ---> 28 ds = yt.load_particles(data)
# ...

# %%
yt.ProjectionPlot(ds, "x", ("dm", "particle_mass"))
# Out:
# yt : [INFO     ] 2023-10-31 14:51:40,222 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-10-31 14:51:40,223 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-10-31 14:51:40,227 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-10-31 14:51:40,228 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-10-31 14:51:40,229 Making a fixed resolution buffer of (('dm', 'particle_mass')) 800 by 800
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 yt.ProjectionPlot(ds, "x", ("dm", "particle_mass"))
#
# File ~/src/yt_general/yt/yt/visualization/plot_window.py:2088, in AxisAlignedProjectionPlot.__init__(self, ds, normal, fields, center, width, axes_unit, weight_field, max_level, origin, fontsize, field_parameters, data_source, method, window_size, buff_size, aspect, moment)
#    2076     proj = ds.proj(
#    2077         fields,
# ...
