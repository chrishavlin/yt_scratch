# %%
import yt 
from inheritance_explorer import ClassGraphTree

# %%
cgt = ClassGraphTree(yt.utilities.io_handler.BaseParticleIOHandler, 
                     funcname='_read_particle_fields')

# %%
cgt.show_graph()

# %%
cgt.display_code_comparison()

# %%
cgt = ClassGraphTree(yt.utilities.io_handler.BaseParticleIOHandler, 
                     funcname='_read_particle_data_file')
cgt.display_code_comparison()
