# %%
import yt
ds = yt.load("snapshot_033")
# Out:
# yt : [INFO     ] 2022-01-26 17:56:57,436 Parameters: current_time              = 4.343952725460923e+17 s
# yt : [INFO     ] 2022-01-26 17:56:57,436 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-01-26 17:56:57,437 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-26 17:56:57,438 Parameters: domain_right_edge         = [25. 25. 25.]
# yt : [INFO     ] 2022-01-26 17:56:57,438 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2022-01-26 17:56:57,438 Parameters: current_redshift          = -4.811891664902035e-05
# yt : [INFO     ] 2022-01-26 17:56:57,439 Parameters: omega_lambda              = 0.762
# yt : [INFO     ] 2022-01-26 17:56:57,439 Parameters: omega_matter              = 0.238
# yt : [INFO     ] 2022-01-26 17:56:57,440 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2022-01-26 17:56:57,440 Parameters: hubble_constant           = 0.73

# %%
yt.SlicePlot(ds,"x",("PartType0","Density"))
# Out:
# yt : [INFO     ] 2022-01-26 17:57:08,679 Allocating for 4.194e+06 particles
# Loading particle index: 100%|██████████████████████████████████| 12/12 [00:00<00:00, 482.80it/s]
# yt : [INFO     ] 2022-01-26 17:57:11,479 xlim = 0.000000 25.000000
# yt : [INFO     ] 2022-01-26 17:57:11,480 ylim = 0.000000 25.000000
# yt : [INFO     ] 2022-01-26 17:57:11,481 xlim = 0.000000 25.000000
# yt : [INFO     ] 2022-01-26 17:57:11,481 ylim = 0.000000 25.000000
# yt : [INFO     ] 2022-01-26 17:57:11,489 Making a fixed resolution buffer of (('PartType0', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds.domain_center

# %%
ds.domain_left_edge

# %%
ds.domain_right_edge
