# %%
import yt

# %%
ds = yt.load("enzo_tiny_cosmology/DD0001/DD0001")
yt.SlicePlot(ds, "x", ("enzo", "Density"))
# Out:
# yt : [INFO     ] 2023-08-11 17:20:12,615 Parameters: current_time              = 5.8164677884124
# yt : [INFO     ] 2023-08-11 17:20:12,616 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:20:12,617 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:20:12,617 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:20:12,618 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:20:12,619 Parameters: current_redshift          = 12.773900078899
# yt : [INFO     ] 2023-08-11 17:20:12,619 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:20:12,620 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:20:12,620 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:20:12,620 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0003/DD0003")
yt.SlicePlot(ds, "x", ("enzo", "Density"))
# Out:
# yt : [INFO     ] 2023-08-11 17:20:24,981 Parameters: current_time              = 15.816500813111
# yt : [INFO     ] 2023-08-11 17:20:24,982 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:20:24,983 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:20:24,984 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:20:24,985 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:20:24,985 Parameters: current_redshift          = 6.0649424389747
# yt : [INFO     ] 2023-08-11 17:20:24,985 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:20:24,986 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:20:24,986 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:20:24,986 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0004/DD0004")
yt.SlicePlot(ds, "x", ("enzo", "Density"))
# Out:
# yt : [INFO     ] 2023-08-11 17:20:37,549 Parameters: current_time              = 20.816480130299
# yt : [INFO     ] 2023-08-11 17:20:37,550 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:20:37,551 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:20:37,552 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:20:37,552 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:20:37,552 Parameters: current_redshift          = 4.8791075773589
# yt : [INFO     ] 2023-08-11 17:20:37,553 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:20:37,553 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:20:37,554 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:20:37,554 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0010/DD0010")
yt.SlicePlot(ds, "x", ("enzo", "Density"))
# Out:
# yt : [INFO     ] 2023-08-11 17:20:47,687 Parameters: current_time              = 50.816545114263
# yt : [INFO     ] 2023-08-11 17:20:47,687 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:20:47,688 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:20:47,689 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:20:47,689 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:20:47,690 Parameters: current_redshift          = 2.219583420036
# yt : [INFO     ] 2023-08-11 17:20:47,690 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:20:47,690 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:20:47,691 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:20:47,691 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0020/DD0020")
yt.SlicePlot(ds, "x", ("enzo", "Density"), width=(20, "Mpc"))
# Out:
# yt : [INFO     ] 2023-08-11 17:22:09,553 Parameters: current_time              = 100.81669692729
# yt : [INFO     ] 2023-08-11 17:22:09,554 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:22:09,555 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:22:09,556 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:22:09,556 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:22:09,557 Parameters: current_redshift          = 0.98870235716941
# yt : [INFO     ] 2023-08-11 17:22:09,557 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:22:09,558 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:22:09,558 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:22:09,558 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0010/DD0010")
yt.SlicePlot(ds, "x", ("enzo", "Density"), width=(20, "Mpc"))
# Out:
# yt : [INFO     ] 2023-08-11 17:21:50,688 Parameters: current_time              = 50.816545114263
# yt : [INFO     ] 2023-08-11 17:21:50,689 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:21:50,690 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:21:50,690 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:21:50,691 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:21:50,691 Parameters: current_redshift          = 2.219583420036
# yt : [INFO     ] 2023-08-11 17:21:50,692 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:21:50,692 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:21:50,692 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:21:50,693 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0011/DD0011")
yt.SlicePlot(ds, "x", ("enzo", "Density"), width=(20, "Mpc"))
# Out:
# yt : [INFO     ] 2023-08-11 17:22:21,406 Parameters: current_time              = 55.816502139314
# yt : [INFO     ] 2023-08-11 17:22:21,407 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:22:21,407 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:22:21,408 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:22:21,409 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:22:21,409 Parameters: current_redshift          = 2.0189625110957
# yt : [INFO     ] 2023-08-11 17:22:21,409 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:22:21,410 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:22:21,411 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:22:21,411 Parameters: hubble_constant           = 0.702
# ...

# %%
ds = yt.load("enzo_tiny_cosmology/DD0012/DD0012")
yt.SlicePlot(ds, "x", ("enzo", "Density"), width=(20, "Mpc"))
# Out:
# yt : [INFO     ] 2023-08-11 17:22:31,208 Parameters: current_time              = 60.816631242975
# yt : [INFO     ] 2023-08-11 17:22:31,209 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2023-08-11 17:22:31,210 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-11 17:22:31,210 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-11 17:22:31,211 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-11 17:22:31,211 Parameters: current_redshift          = 1.8456156964435
# yt : [INFO     ] 2023-08-11 17:22:31,212 Parameters: omega_lambda              = 0.727
# yt : [INFO     ] 2023-08-11 17:22:31,212 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2023-08-11 17:22:31,212 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-08-11 17:22:31,213 Parameters: hubble_constant           = 0.702
# ...
