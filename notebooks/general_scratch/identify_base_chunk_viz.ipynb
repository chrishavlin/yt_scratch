# %%
import yt
# ds = yt.load_sample("PopIII_mini")
ds = yt.load("PopIII_mini/DD0034/DD0034")
sp = ds.sphere(ds.arr( [11.]*3, 'kpc'), ds.quan(2, 'kpc'))
slc = yt.SlicePlot(ds, "z", ("enzo", "Density"), data_source=sp)
slc.save("/var/tmp/")
# Out:
# yt : [INFO     ] 2023-08-17 10:37:04,794 Parameters: current_time              = 29.703884802009
# yt : [INFO     ] 2023-08-17 10:37:04,795 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-08-17 10:37:04,796 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-08-17 10:37:04,797 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-08-17 10:37:04,797 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2023-08-17 10:37:04,798 Parameters: current_redshift          = 15.393137305306
# yt : [INFO     ] 2023-08-17 10:37:04,798 Parameters: omega_lambda              = 0.734
# yt : [INFO     ] 2023-08-17 10:37:04,798 Parameters: omega_matter              = 0.2659
# yt : [INFO     ] 2023-08-17 10:37:04,799 Parameters: omega_radiation           = 0.0001
# yt : [INFO     ] 2023-08-17 10:37:04,799 Parameters: hubble_constant           = 0.71
# ...

# %%
slc = yt.SlicePlot(ds, "z", ("enzo", "Density"))
slc.annotate_grids()
# Out:
# yt : [INFO     ] 2023-08-17 10:50:06,257 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:06,258 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:06,262 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:06,263 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:06,266 Making a fixed resolution buffer of (('enzo', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
sp = ds.sphere(ds.arr( [11.]*3, 'kpc'), ds.quan(2, 'kpc'))
slc = yt.SlicePlot(ds, "z", ("index", "ones"), data_source=sp)
slc.annotate_grids()
# Out:
# yt : [INFO     ] 2023-08-17 10:49:36,153 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:49:36,154 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:49:36,158 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:49:36,159 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:49:36,161 Making a fixed resolution buffer of (('index', 'ones')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
sp = ds.sphere(ds.arr( [11.]*3, 'kpc'), ds.quan(.5, 'kpc'))
slc = yt.SlicePlot(ds, "z", ("index", "ones"), data_source=sp)
slc.annotate_grids()
# Out:
# yt : [INFO     ] 2023-08-17 10:50:41,836 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:41,836 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:41,838 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:41,839 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-08-17 10:50:41,840 Making a fixed resolution buffer of (('index', 'ones')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
len(ds.index.grids)
# Out:
# 886

# %%
sp = ds.sphere(ds.arr( [11.]*3, 'kpc'), ds.quan(.5, 'kpc'))

# %%
len(sp._grids)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 len(sp._grids)
#
# TypeError: object of type 'NoneType' has no len()
