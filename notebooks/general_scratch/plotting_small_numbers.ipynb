# %%
import yt 
import numpy as np

# %%
data = {'density': 10**np.random.uniform(-198, -135, (256, 256, 256))}
ds = yt.load_uniform_grid(data, data['density'].shape)
yt.SlicePlot(ds, 'x', 'density')
# Out:
# yt : [INFO     ] 2023-06-21 09:54:49,517 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-06-21 09:54:49,517 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2023-06-21 09:54:49,518 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-21 09:54:49,519 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-21 09:54:49,520 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-06-21 09:54:49,623 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:49,623 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:49,626 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:49,626 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:49,629 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
# Out:
# yt : [INFO     ] 2023-06-21 09:53:52,094 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-06-21 09:53:52,094 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2023-06-21 09:53:52,095 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-21 09:53:52,096 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-21 09:53:52,096 Parameters: cosmological_simulation   = 0

# %%
# Out:
# yt : [INFO     ] 2023-06-21 09:54:16,319 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:16,319 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:16,322 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:16,322 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-06-21 09:54:16,337 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
